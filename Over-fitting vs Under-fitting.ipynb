# %% [markdown]
# ## Over-fitting vs Under-fitting
#
# When the accuracy of your model on the validation data would peak after training for a number of epochs, and would then start decreasing.
#
# In other words, your model would overfit to the training data. Learning how to deal with overfitting is important. Although it's often possible to achieve high accuracy on the training set, what we really want is to develop models that generalize well to a testing data (or data they haven't seen before).
#
# The opposite of overfitting is underfitting. Underfitting occurs when there is still room for improvement on the test data. This can happen for a number of reasons: If the model is not powerful enough, is over-regularized, or has simply not been trained long enough. This means the network has not learned the relevant patterns in the training data.
#
# If you train for too long though, the model will start to overfit and learn patterns from the training data that don't generalize to the test data. We need to strike a balance. Understanding how to train for an appropriate number of epochs as we'll explore below is a useful skill.
#
# ### Solution:
# To prevent overfitting, the best solution is to use more training data. A model trained on more data will naturally generalize better. When that is no longer possible, the next best solution is to use techniques like regularization. These place constraints on the quantity and type of information your model can store. If a network can only afford to memorize a small number of patterns, the optimization process will force it to focus on the most prominent patterns, which have a better chance of generalizing well.
#
# In this notebook, I'll explore two common regularization techniques—weight regularization and dropout—and use them to improve our IMDB movie review classification notebook.

# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(tf.__version__)
# Out:
# 1.10.0

# %% [markdown]
# ## Downloading the IMDB Dataset
#
# Rather than using an embedding, here we will multi-hot encode the sentences. This model will quickly overfit to the training set. It will be used to demonstrate when overfitting occurs, and how to fight it.
#
# Multi-hot-encoding our lists means turning them into vectors of 0s and 1s. Concretely, this would mean for instance turning the sequence [3, 5] into a 2500-dimensional vector(Memory Problem but you can increase the NUM_WORDS Size) that would be all-zeros except for indices 3 and 5, which would be ones.

# %%
NUM_WORDS = 2500

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # set specific indices of results[i] to 1s
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

# %% [markdown]
# Let's look at one of the resulting multi-hot vectors. The word indices are sorted by frequency, so it is expected that there are more 1-values near index zero, as we can see in this plot:

# %%
plt.plot(train_data[0])

# %% [markdown]
# ## Demonstrate overfitting
# The simplest way to prevent overfitting is to reduce the size of the model, i.e. the number of learnable parameters in the model (which is determined by the number of layers and the number of units per layer). In deep learning, the number of learnable parameters in a model is often referred to as the model's "capacity". Intuitively, a model with more parameters will have more "memorization capacity" and therefore will be able to easily learn a perfect dictionary-like mapping between training samples and their targets, a mapping without any generalization power, but this would be useless when making predictions on previously unseen data.
#
# Always keep this in mind: deep learning models tend to be good at fitting to the training data, but the real challenge is generalization, not fitting.
#
# On the other hand, if the network has limited memorization resources, it will not be able to learn the mapping as easily. To minimize its loss, it will have to learn compressed representations that have more predictive power. At the same time, if you make your model too small, it will have difficulty fitting to the training data. There is a balance between "too much capacity" and "not enough capacity".
#
# Unfortunately, there is no magical formula to determine the right size or architecture of your model (in terms of the number of layers, or what the right size for each layer). You will have to experiment using a series of different architectures.
#
# To find an appropriate model size, it's best to start with relatively few layers and parameters, then begin increasing the size of the layers or adding new layers until you see diminishing returns on the validation loss. Let's try this on our movie review classification network.
#
# We'll create a simple model using only Dense layers as a baseline, then create smaller and larger versions, and compare them.

# %% [markdown]
# ### Create a baseline model

# %%
baseline_model = keras.Sequential([
        # `input_shape` is only required here so that `.summary` works. 
    keras.layers.Dense(16,activation=tf.nn.relu,input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16,activation=tf.nn.relu),
    keras.layers.Dense(1,activation=tf.nn.sigmoid)
])

baseline_model.compile(optimizer="adam",loss="binary_crossentropy", metrics = ['accuracy','binary_crossentropy'])

baseline_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 16)                40016
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 40,305
# Trainable params: 40,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 294s - loss: 0.5136 - acc: 0.7743 - binary_crossentropy: 0.5136 - val_loss: 0.3611 - val_acc: 0.8600 - val_binary_crossentropy: 0.3611
# Epoch 2/20
#  - 2s - loss: 0.3030 - acc: 0.8819 - binary_crossentropy: 0.3030 - val_loss: 0.3009 - val_acc: 0.8774 - val_binary_crossentropy: 0.3009
# Epoch 3/20
#  - 2s - loss: 0.2580 - acc: 0.8972 - binary_crossentropy: 0.2580 - val_loss: 0.2965 - val_acc: 0.8777 - val_binary_crossentropy: 0.2965
# Epoch 4/20
#  - 2s - loss: 0.2405 - acc: 0.9060 - binary_crossentropy: 0.2405 - val_loss: 0.3012 - val_acc: 0.8755 - val_binary_crossentropy: 0.3012
# Epoch 5/20
#  - 2s - loss: 0.2315 - acc: 0.9096 - binary_crossentropy: 0.2315 - val_loss: 0.3104 - val_acc: 0.8718 - val_binary_crossentropy: 0.3104
# Epoch 6/20
#  - 2s - loss: 0.2251 - acc: 0.9136 - binary_crossentropy: 0.2251 - val_loss: 0.3159 - val_acc: 0.8718 - val_binary_crossentropy: 0.3159
# Epoch 7/20
#  - 2s - loss: 0.2204 - acc: 0.9137 - binary_crossentropy: 0.2204 - val_loss: 0.3217 - val_acc: 0.8708 - val_binary_crossentropy: 0.3217
# Epoch 8/20
#  - 2s - loss: 0.2121 - acc: 0.9177 - binary_crossentropy: 0.2121 - val_loss: 0.3292 - val_acc: 0.8694 - val_binary_crossentropy: 0.3292
# Epoch 9/20
#  - 2s - loss: 0.2033 - acc: 0.9217 - binary_crossentropy: 0.2033 - val_loss: 0.3368 - val_acc: 0.8671 - val_binary_crossentropy: 0.3368
# Epoch 10/20
#  - 2s - loss: 0.1933 - acc: 0.9269 - binary_crossentropy: 0.1933 - val_loss: 0.3402 - val_acc: 0.8673 - val_binary_crossentropy: 0.3402
# Epoch 11/20
#  - 2s - loss: 0.1838 - acc: 0.9304 - binary_crossentropy: 0.1838 - val_loss: 0.3455 - val_acc: 0.8673 - val_binary_crossentropy: 0.3455
# Epoch 12/20
#  - 2s - loss: 0.1740 - acc: 0.9329 - binary_crossentropy: 0.1740 - val_loss: 0.3528 - val_acc: 0.8669 - val_binary_crossentropy: 0.3528
# Epoch 13/20
#  - 2s - loss: 0.1595 - acc: 0.9418 - binary_crossentropy: 0.1595 - val_loss: 0.3658 - val_acc: 0.8630 - val_binary_crossentropy: 0.3658
# Epoch 14/20
#  - 2s - loss: 0.1517 - acc: 0.9444 - binary_crossentropy: 0.1517 - val_loss: 0.3821 - val_acc: 0.8581 - val_binary_crossentropy: 0.3821
# Epoch 15/20
#  - 2s - loss: 0.1386 - acc: 0.9496 - binary_crossentropy: 0.1386 - val_loss: 0.3885 - val_acc: 0.8614 - val_binary_crossentropy: 0.3885
# Epoch 16/20
#  - 2s - loss: 0.1286 - acc: 0.9552 - binary_crossentropy: 0.1286 - val_loss: 0.4103 - val_acc: 0.8598 - val_binary_crossentropy: 0.4103
# Epoch 17/20
#  - 2s - loss: 0.1205 - acc: 0.9577 - binary_crossentropy: 0.1205 - val_loss: 0.4165 - val_acc: 0.8595 - val_binary_crossentropy: 0.4165
# Epoch 18/20
#  - 2s - loss: 0.1105 - acc: 0.9614 - binary_crossentropy: 0.1105 - val_loss: 0.4330 - val_acc: 0.8580 - val_binary_crossentropy: 0.4330
# Epoch 19/20
#  - 2s - loss: 0.1018 - acc: 0.9653 - binary_crossentropy: 0.1018 - val_loss: 0.4570 - val_acc: 0.8563 - val_binary_crossentropy: 0.4570
# Epoch 20/20
#  - 2s - loss: 0.0950 - acc: 0.9678 - binary_crossentropy: 0.0950 - val_loss: 0.4731 - val_acc: 0.8551 - val_binary_crossentropy: 0.4731

# %% [markdown]
# ## Create a smaller model
# Let's create a model with less hidden units to compare against the baseline model that we just created:

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

smaller_model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 4)                 10004
# _________________________________________________________________
# dense_7 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 10,029
# Trainable params: 10,029
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# And train the model using the same data:

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 332s - loss: 0.6154 - acc: 0.7190 - binary_crossentropy: 0.6154 - val_loss: 0.5074 - val_acc: 0.8254 - val_binary_crossentropy: 0.5074
# Epoch 2/20
#  - 48s - loss: 0.3981 - acc: 0.8582 - binary_crossentropy: 0.3981 - val_loss: 0.3546 - val_acc: 0.8638 - val_binary_crossentropy: 0.3546
# Epoch 3/20
#  - 2s - loss: 0.3064 - acc: 0.8861 - binary_crossentropy: 0.3064 - val_loss: 0.3127 - val_acc: 0.8756 - val_binary_crossentropy: 0.3127
# Epoch 4/20
#  - 2s - loss: 0.2716 - acc: 0.8969 - binary_crossentropy: 0.2716 - val_loss: 0.3003 - val_acc: 0.8766 - val_binary_crossentropy: 0.3003
# Epoch 5/20
#  - 3s - loss: 0.2531 - acc: 0.9027 - binary_crossentropy: 0.2531 - val_loss: 0.2968 - val_acc: 0.8778 - val_binary_crossentropy: 0.2968
# Epoch 6/20
#  - 2s - loss: 0.2414 - acc: 0.9064 - binary_crossentropy: 0.2414 - val_loss: 0.2963 - val_acc: 0.8776 - val_binary_crossentropy: 0.2963
# Epoch 7/20
#  - 2s - loss: 0.2332 - acc: 0.9095 - binary_crossentropy: 0.2332 - val_loss: 0.3001 - val_acc: 0.8762 - val_binary_crossentropy: 0.3001
# Epoch 8/20
#  - 2s - loss: 0.2278 - acc: 0.9117 - binary_crossentropy: 0.2278 - val_loss: 0.3019 - val_acc: 0.8763 - val_binary_crossentropy: 0.3019
# Epoch 9/20
#  - 2s - loss: 0.2240 - acc: 0.9120 - binary_crossentropy: 0.2240 - val_loss: 0.3070 - val_acc: 0.8744 - val_binary_crossentropy: 0.3070
# Epoch 10/20
#  - 2s - loss: 0.2202 - acc: 0.9138 - binary_crossentropy: 0.2202 - val_loss: 0.3108 - val_acc: 0.8737 - val_binary_crossentropy: 0.3108
# Epoch 11/20
#  - 2s - loss: 0.2181 - acc: 0.9164 - binary_crossentropy: 0.2181 - val_loss: 0.3152 - val_acc: 0.8723 - val_binary_crossentropy: 0.3152
# Epoch 12/20
#  - 2s - loss: 0.2154 - acc: 0.9165 - binary_crossentropy: 0.2154 - val_loss: 0.3208 - val_acc: 0.8702 - val_binary_crossentropy: 0.3208
# Epoch 13/20
#  - 2s - loss: 0.2132 - acc: 0.9155 - binary_crossentropy: 0.2132 - val_loss: 0.3231 - val_acc: 0.8720 - val_binary_crossentropy: 0.3231
# Epoch 14/20
#  - 2s - loss: 0.2124 - acc: 0.9173 - binary_crossentropy: 0.2124 - val_loss: 0.3267 - val_acc: 0.8708 - val_binary_crossentropy: 0.3267
# Epoch 15/20
#  - 2s - loss: 0.2108 - acc: 0.9171 - binary_crossentropy: 0.2108 - val_loss: 0.3302 - val_acc: 0.8697 - val_binary_crossentropy: 0.3302
# Epoch 16/20
#  - 2s - loss: 0.2092 - acc: 0.9168 - binary_crossentropy: 0.2092 - val_loss: 0.3360 - val_acc: 0.8686 - val_binary_crossentropy: 0.3360
# Epoch 17/20
#  - 2s - loss: 0.2089 - acc: 0.9184 - binary_crossentropy: 0.2089 - val_loss: 0.3404 - val_acc: 0.8658 - val_binary_crossentropy: 0.3404
# Epoch 18/20
#  - 2s - loss: 0.2088 - acc: 0.9163 - binary_crossentropy: 0.2088 - val_loss: 0.3394 - val_acc: 0.8685 - val_binary_crossentropy: 0.3394
# Epoch 19/20
#  - 2s - loss: 0.2070 - acc: 0.9186 - binary_crossentropy: 0.2070 - val_loss: 0.3425 - val_acc: 0.8686 - val_binary_crossentropy: 0.3425
# Epoch 20/20
#  - 2s - loss: 0.2057 - acc: 0.9199 - binary_crossentropy: 0.2057 - val_loss: 0.3454 - val_acc: 0.8672 - val_binary_crossentropy: 0.3454

# %% [markdown]
# ## Create a bigger model
# As an exercise, you can create an even larger model, and see how quickly it begins overfitting. Next, let's add to this benchmark a network that has much more capacity, far more than the problem would warrant:

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 512)               1280512
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 1,543,681
# Trainable params: 1,543,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 28s - loss: 0.3882 - acc: 0.8232 - binary_crossentropy: 0.3882 - val_loss: 0.2930 - val_acc: 0.8746 - val_binary_crossentropy: 0.2930
# Epoch 2/20
#  - 14s - loss: 0.2143 - acc: 0.9180 - binary_crossentropy: 0.2143 - val_loss: 0.3070 - val_acc: 0.8699 - val_binary_crossentropy: 0.3070
# Epoch 3/20
#  - 15s - loss: 0.1079 - acc: 0.9650 - binary_crossentropy: 0.1079 - val_loss: 0.3745 - val_acc: 0.8568 - val_binary_crossentropy: 0.3745
# Epoch 4/20
#  - 16s - loss: 0.0232 - acc: 0.9955 - binary_crossentropy: 0.0232 - val_loss: 0.4839 - val_acc: 0.8682 - val_binary_crossentropy: 0.4839
# Epoch 5/20
#  - 15s - loss: 0.0028 - acc: 0.9998 - binary_crossentropy: 0.0028 - val_loss: 0.5893 - val_acc: 0.8701 - val_binary_crossentropy: 0.5893
# Epoch 6/20
#  - 16s - loss: 0.0012 - acc: 1.0000 - binary_crossentropy: 0.0012 - val_loss: 0.6206 - val_acc: 0.8696 - val_binary_crossentropy: 0.6206
# Epoch 7/20
#  - 16s - loss: 3.3059e-04 - acc: 1.0000 - binary_crossentropy: 3.3059e-04 - val_loss: 0.6511 - val_acc: 0.8697 - val_binary_crossentropy: 0.6511
# Epoch 8/20
#  - 16s - loss: 2.1041e-04 - acc: 1.0000 - binary_crossentropy: 2.1041e-04 - val_loss: 0.6746 - val_acc: 0.8706 - val_binary_crossentropy: 0.6746
# Epoch 9/20
#  - 17s - loss: 1.5284e-04 - acc: 1.0000 - binary_crossentropy: 1.5284e-04 - val_loss: 0.6929 - val_acc: 0.8707 - val_binary_crossentropy: 0.6929
# Epoch 10/20
#  - 17s - loss: 1.1707e-04 - acc: 1.0000 - binary_crossentropy: 1.1707e-04 - val_loss: 0.7080 - val_acc: 0.8708 - val_binary_crossentropy: 0.7080
# Epoch 11/20
#  - 17s - loss: 9.2639e-05 - acc: 1.0000 - binary_crossentropy: 9.2639e-05 - val_loss: 0.7214 - val_acc: 0.8708 - val_binary_crossentropy: 0.7214
# Epoch 12/20
#  - 17s - loss: 7.5061e-05 - acc: 1.0000 - binary_crossentropy: 7.5061e-05 - val_loss: 0.7334 - val_acc: 0.8710 - val_binary_crossentropy: 0.7334
# Epoch 13/20
#  - 17s - loss: 6.1861e-05 - acc: 1.0000 - binary_crossentropy: 6.1861e-05 - val_loss: 0.7444 - val_acc: 0.8712 - val_binary_crossentropy: 0.7444
# Epoch 14/20
#  - 18s - loss: 5.1766e-05 - acc: 1.0000 - binary_crossentropy: 5.1766e-05 - val_loss: 0.7545 - val_acc: 0.8710 - val_binary_crossentropy: 0.7545
# Epoch 15/20
#  - 18s - loss: 4.3765e-05 - acc: 1.0000 - binary_crossentropy: 4.3765e-05 - val_loss: 0.7640 - val_acc: 0.8711 - val_binary_crossentropy: 0.7640
# Epoch 16/20
#  - 18s - loss: 3.7437e-05 - acc: 1.0000 - binary_crossentropy: 3.7437e-05 - val_loss: 0.7727 - val_acc: 0.8712 - val_binary_crossentropy: 0.7727
# Epoch 17/20
#  - 18s - loss: 3.2351e-05 - acc: 1.0000 - binary_crossentropy: 3.2351e-05 - val_loss: 0.7811 - val_acc: 0.8712 - val_binary_crossentropy: 0.7811
# Epoch 18/20
#  - 18s - loss: 2.8158e-05 - acc: 1.0000 - binary_crossentropy: 2.8158e-05 - val_loss: 0.7886 - val_acc: 0.8717 - val_binary_crossentropy: 0.7886
# Epoch 19/20
#  - 18s - loss: 2.4667e-05 - acc: 1.0000 - binary_crossentropy: 2.4667e-05 - val_loss: 0.7958 - val_acc: 0.8716 - val_binary_crossentropy: 0.7958
# Epoch 20/20
#  - 18s - loss: 2.1758e-05 - acc: 1.0000 - binary_crossentropy: 2.1758e-05 - val_loss: 0.8030 - val_acc: 0.8716 - val_binary_crossentropy: 0.8030

# %% [markdown]
# ## Plot the training and validation loss
# The solid lines show the training loss, and the dashed lines show the validation loss (remember: a lower validation loss indicates a better model). Here, the smaller network begins overfitting later than the baseline model (after 6 epochs rather than 4) and its performance degrades much more slowly once it starts overfitting.

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))
    
  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %% [markdown]
# Notice that the larger network begins overfitting almost right away, after just one epoch, and overfits much more severely. The more capacity the network has, the quicker it will be able to model the training data (resulting in a low training loss), but the more susceptible it is to overfitting (resulting in a large difference between the training and validation loss).

# %% [markdown]
# ## Strategies
#
# Add weight regularization
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the "L2 norm" of the weights).
#
# L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# In tf.keras, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 377s - loss: 0.5647 - acc: 0.7676 - binary_crossentropy: 0.5220 - val_loss: 0.4163 - val_acc: 0.8577 - val_binary_crossentropy: 0.3764
# Epoch 2/20
#  - 176s - loss: 0.3556 - acc: 0.8805 - binary_crossentropy: 0.3151 - val_loss: 0.3453 - val_acc: 0.8761 - val_binary_crossentropy: 0.3044
# Epoch 3/20
#  - 3s - loss: 0.3075 - acc: 0.8972 - binary_crossentropy: 0.2665 - val_loss: 0.3344 - val_acc: 0.8792 - val_binary_crossentropy: 0.2933
# Epoch 4/20
#  - 2s - loss: 0.2879 - acc: 0.9052 - binary_crossentropy: 0.2467 - val_loss: 0.3358 - val_acc: 0.8772 - val_binary_crossentropy: 0.2949
# Epoch 5/20
#  - 2s - loss: 0.2796 - acc: 0.9068 - binary_crossentropy: 0.2388 - val_loss: 0.3409 - val_acc: 0.8746 - val_binary_crossentropy: 0.3005
# Epoch 6/20
#  - 4s - loss: 0.2736 - acc: 0.9077 - binary_crossentropy: 0.2333 - val_loss: 0.3429 - val_acc: 0.8744 - val_binary_crossentropy: 0.3031
# Epoch 7/20
#  - 4s - loss: 0.2688 - acc: 0.9102 - binary_crossentropy: 0.2293 - val_loss: 0.3456 - val_acc: 0.8736 - val_binary_crossentropy: 0.3064
# Epoch 8/20
#  - 2s - loss: 0.2654 - acc: 0.9110 - binary_crossentropy: 0.2263 - val_loss: 0.3482 - val_acc: 0.8732 - val_binary_crossentropy: 0.3094
# Epoch 9/20
#  - 2s - loss: 0.2619 - acc: 0.9122 - binary_crossentropy: 0.2233 - val_loss: 0.3508 - val_acc: 0.8721 - val_binary_crossentropy: 0.3125
# Epoch 10/20
#  - 2s - loss: 0.2614 - acc: 0.9118 - binary_crossentropy: 0.2232 - val_loss: 0.3527 - val_acc: 0.8724 - val_binary_crossentropy: 0.3147
# Epoch 11/20
#  - 2s - loss: 0.2560 - acc: 0.9148 - binary_crossentropy: 0.2180 - val_loss: 0.3544 - val_acc: 0.8706 - val_binary_crossentropy: 0.3165
# Epoch 12/20
#  - 2s - loss: 0.2543 - acc: 0.9141 - binary_crossentropy: 0.2162 - val_loss: 0.3549 - val_acc: 0.8713 - val_binary_crossentropy: 0.3170
# Epoch 13/20
#  - 2s - loss: 0.2492 - acc: 0.9171 - binary_crossentropy: 0.2112 - val_loss: 0.3649 - val_acc: 0.8677 - val_binary_crossentropy: 0.3270
# Epoch 14/20
#  - 2s - loss: 0.2459 - acc: 0.9188 - binary_crossentropy: 0.2078 - val_loss: 0.3605 - val_acc: 0.8697 - val_binary_crossentropy: 0.3223
# Epoch 15/20
#  - 2s - loss: 0.2406 - acc: 0.9206 - binary_crossentropy: 0.2021 - val_loss: 0.3671 - val_acc: 0.8668 - val_binary_crossentropy: 0.3286
# Epoch 16/20
#  - 2s - loss: 0.2417 - acc: 0.9210 - binary_crossentropy: 0.2029 - val_loss: 0.3845 - val_acc: 0.8611 - val_binary_crossentropy: 0.3454
# Epoch 17/20
#  - 2s - loss: 0.2376 - acc: 0.9210 - binary_crossentropy: 0.1981 - val_loss: 0.3728 - val_acc: 0.8667 - val_binary_crossentropy: 0.3329
# Epoch 18/20
#  - 2s - loss: 0.2287 - acc: 0.9265 - binary_crossentropy: 0.1885 - val_loss: 0.3683 - val_acc: 0.8684 - val_binary_crossentropy: 0.3279
# Epoch 19/20
#  - 2s - loss: 0.2216 - acc: 0.9316 - binary_crossentropy: 0.1807 - val_loss: 0.3747 - val_acc: 0.8668 - val_binary_crossentropy: 0.3336
# Epoch 20/20
#  - 2s - loss: 0.2186 - acc: 0.9330 - binary_crossentropy: 0.1770 - val_loss: 0.3782 - val_acc: 0.8677 - val_binary_crossentropy: 0.3362

# %% [markdown]
# l2(0.001) means that every coefficient in the weight matrix of the layer will add 0.001 * weight_coefficient_value**2 to the total loss of the network. Note that because this penalty is only added at training time, the loss for this network will be much higher at training than at test time.
#
# Here's the impact of our L2 regularization penalty:

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %% [markdown]
# As you can see, the L2 regularized model has become much more resistant to overfitting than the baseline model, even though both models have the same number of parameters.

# %% [markdown]
# ## Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto. Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1]. The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In tf.keras you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our IMDB network to see how well they do at reducing overfitting:

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 15s - loss: 0.6613 - acc: 0.5912 - binary_crossentropy: 0.6613 - val_loss: 0.5803 - val_acc: 0.7743 - val_binary_crossentropy: 0.5803
# Epoch 2/20
#  - 2s - loss: 0.5409 - acc: 0.7358 - binary_crossentropy: 0.5409 - val_loss: 0.4407 - val_acc: 0.8541 - val_binary_crossentropy: 0.4407
# Epoch 3/20
#  - 2s - loss: 0.4471 - acc: 0.8135 - binary_crossentropy: 0.4471 - val_loss: 0.3569 - val_acc: 0.8712 - val_binary_crossentropy: 0.3569
# Epoch 4/20
#  - 2s - loss: 0.3913 - acc: 0.8476 - binary_crossentropy: 0.3913 - val_loss: 0.3099 - val_acc: 0.8779 - val_binary_crossentropy: 0.3099
# Epoch 5/20
#  - 2s - loss: 0.3502 - acc: 0.8693 - binary_crossentropy: 0.3502 - val_loss: 0.2953 - val_acc: 0.8782 - val_binary_crossentropy: 0.2953
# Epoch 6/20
#  - 2s - loss: 0.3225 - acc: 0.8838 - binary_crossentropy: 0.3225 - val_loss: 0.2915 - val_acc: 0.8798 - val_binary_crossentropy: 0.2915
# Epoch 7/20
#  - 2s - loss: 0.3063 - acc: 0.8931 - binary_crossentropy: 0.3063 - val_loss: 0.2912 - val_acc: 0.8769 - val_binary_crossentropy: 0.2912
# Epoch 8/20
#  - 2s - loss: 0.2932 - acc: 0.8970 - binary_crossentropy: 0.2932 - val_loss: 0.2923 - val_acc: 0.8782 - val_binary_crossentropy: 0.2923
# Epoch 9/20
#  - 2s - loss: 0.2758 - acc: 0.9032 - binary_crossentropy: 0.2758 - val_loss: 0.2990 - val_acc: 0.8791 - val_binary_crossentropy: 0.2990
# Epoch 10/20
#  - 2s - loss: 0.2627 - acc: 0.9088 - binary_crossentropy: 0.2627 - val_loss: 0.2983 - val_acc: 0.8754 - val_binary_crossentropy: 0.2983
# Epoch 11/20
#  - 2s - loss: 0.2551 - acc: 0.9104 - binary_crossentropy: 0.2551 - val_loss: 0.3050 - val_acc: 0.8770 - val_binary_crossentropy: 0.3050
# Epoch 12/20
#  - 2s - loss: 0.2460 - acc: 0.9120 - binary_crossentropy: 0.2460 - val_loss: 0.3124 - val_acc: 0.8758 - val_binary_crossentropy: 0.3124
# Epoch 13/20
#  - 2s - loss: 0.2335 - acc: 0.9173 - binary_crossentropy: 0.2335 - val_loss: 0.3189 - val_acc: 0.8749 - val_binary_crossentropy: 0.3189
# Epoch 14/20
#  - 2s - loss: 0.2216 - acc: 0.9209 - binary_crossentropy: 0.2216 - val_loss: 0.3252 - val_acc: 0.8759 - val_binary_crossentropy: 0.3252
# Epoch 15/20
#  - 2s - loss: 0.2165 - acc: 0.9228 - binary_crossentropy: 0.2165 - val_loss: 0.3277 - val_acc: 0.8739 - val_binary_crossentropy: 0.3277
# Epoch 16/20
#  - 2s - loss: 0.2058 - acc: 0.9283 - binary_crossentropy: 0.2058 - val_loss: 0.3445 - val_acc: 0.8746 - val_binary_crossentropy: 0.3445
# Epoch 17/20
#  - 2s - loss: 0.2032 - acc: 0.9304 - binary_crossentropy: 0.2032 - val_loss: 0.3561 - val_acc: 0.8737 - val_binary_crossentropy: 0.3561
# Epoch 18/20
#  - 2s - loss: 0.1952 - acc: 0.9290 - binary_crossentropy: 0.1952 - val_loss: 0.3607 - val_acc: 0.8734 - val_binary_crossentropy: 0.3607
# Epoch 19/20
#  - 2s - loss: 0.1911 - acc: 0.9288 - binary_crossentropy: 0.1911 - val_loss: 0.3674 - val_acc: 0.8700 - val_binary_crossentropy: 0.3674
# Epoch 20/20
#  - 2s - loss: 0.1882 - acc: 0.9320 - binary_crossentropy: 0.1882 - val_loss: 0.3670 - val_acc: 0.8695 - val_binary_crossentropy: 0.3670

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])

# %% [markdown]
# Adding dropout is a clear improvement over the baseline model.
#
# To recap: here the most common ways to prevent overfitting in neural networks:
#
# Get more training data.
# Reduce the capacity of the network.
# Add weight regularization.
# Add dropout.
# And two important approaches not covered in this guide are data-augmentation and batch normalization.
